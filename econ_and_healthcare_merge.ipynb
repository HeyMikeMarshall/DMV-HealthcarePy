# %%
import pandas as pd
import numpy as py

provider_data = pd.read_csv("hcprovider_data\doctor_geo.csv")
hospital_data = pd.read_csv("hcprovider_data\hospital_geo.csv")
econ_data = pd.read_csv("all_econ_data.csv")
provider_data.head()
# Out:
#    Unnamed: 0        lat        lng                                  name  \
# 0           0  38.917568 -77.020726  Howard University Hospital:pulmonary
# 1           1  38.905311 -77.012765                      Shiban Raina, MD
# 2           2  38.905363 -77.018377                         Aziz Salim MD
# 3           3  38.910311 -77.021587                   Abramson Randi C MD
# 4           4  38.910311 -77.021587              Hope Ferdowsian, MD, MPH
#
#                                     vicinity                      placeid  \
# 0  2041 Georgia Avenue Northwest, Washington  ChIJf2TW1OS3t4kRmYwM_D3YU9g
# 1    128 M Street Northwest #050, Washington  ChIJqVHvjcHHt4kR9bkSKfeYk6M
# 2        2175 K Street Northwest, Washington  ChIJO7BERbS3t4kRdCq1JjRVF9c
# 3      1525 7th Street Northwest, Washington  ChIJNcEa_fG3t4kROr29e7EFZJw
# 4      1525 7th Street Northwest, Washington  ChIJxfO-cZTJt4kR1eicxoihlSc
#
#      zip
# 0  20001
# 1  20001
# 2  20001
# 3  20001
# 4  20001

# %%
hospital_data.head()
# Out:
#    Unnamed: 0        lat        lng                          name  \
# 0           0  38.896822 -77.032905      Magellan Health Services
# 1           1  38.903451 -77.040723               Accel E Medical
# 2           2  38.908097 -77.041413  Washington Medical Group, PC
# 3           3  38.903330 -77.039315  Center For Medicare Advocacy
# 4           4  38.905045 -77.042925               Med Star Health
#
#                                             vicinity  \
# 0  1455 Pennsylvania Avenue Northwest # 400, Wash...
# 1  1050 Connecticut Avenue Northwest # 10, Washin...
# 2             1327 18th Street Northwest, Washington
# 3  1025 Connecticut Avenue Northwest # 709, Washi...
# 4             1145 19th Street Northwest, Washington
#
#                        placeid    zip
# 0  ChIJ52L4Api3t4kRg0pAKmwymv4  20004
# 1  ChIJL91LFrm3t4kRLXvL7y2Fzug  20036
# 2  ChIJIUMgc8e3t4kRhbix8nMNpqM  20036
# 3  ChIJUVhSNLm3t4kRS53v-olIkQ8  20036
# 4  ChIJK5vwSLi3t4kR3z6FlYjKVbo  20036

# %%
econ_data.head()
# Out:
#    Zip Code  Total Population  Labor Force Participation Rate  \
# 0     20001             41692                              73
# 1     20002             52867                              72
# 2     20003             26330                              71
# 3     20004              1610                              88
# 4     20005             12311                              84
#
#    Unemployment Rate  Per Capita Income  Total households - Less than $10,000  \
# 0                  5            54353.0                                  1730
# 1                  6            49452.0                                  2501
# 2                  5            63600.0                                   686
# 3                  4           117432.0                                    48
# 4                  2            76658.0                                   751
#
#    Total households - \$10,000-$14,999  Total households - \$15,000-$24,999  \
# ...
