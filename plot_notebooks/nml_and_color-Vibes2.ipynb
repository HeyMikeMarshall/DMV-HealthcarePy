# %% [markdown]
# # Normalized Score and Color Calculator
# -----
#     Use this to calculate a normalized score and color assignments for ZCTA-based demographic data.

# %%
import pandas as pd
from matplotlib.cm import viridis
from matplotlib.colors import to_hex
import matplotlib.pyplot as plt
import numpy as np
import ast
import json

# %%
# Open your CSVs as a dataframes
    
with open('../all_econ_data.csv', newline='\n', encoding='utf-8-sig') as a:
    all_econ_data = pd.read_csv(a)
    
with open('../zcta_map/resources/zip_data.csv', newline='\n', encoding='utf-8-sig') as b:
    zip_data = pd.read_csv(b)
    
with open('../hcprovider_data/doctor_geo.csv', newline='\n', encoding='utf-8-sig') as c:
    doctor_geo = pd.read_csv(c)
    
with open('../hcprovider_data/hospital_geo.csv', newline='\n', encoding='utf-8-sig') as d:
    hospital_geo = pd.read_csv(d)
    
with open('../insurance_data/insurance_data.csv', encoding='utf-8') as e:
    ins_data = pd.read_csv(e)

# %%
all_econ_data.head()
# Out:
#    Zip Code  Total Population  Labor Force Participation Rate  \
# 0     20001             41692                              73
# 1     20002             52867                              72
# 2     20003             26330                              71
# 3     20004              1610                              88
# 4     20005             12311                              84
#
#    Unemployment Rate  Per Capita Income  Total households - Less than $10,000  \
# 0                  5            54353.0                                  1730
# 1                  6            49452.0                                  2501
# 2                  5            63600.0                                   686
# 3                  4           117432.0                                    48
# 4                  2            76658.0                                   751
#
#    Total households - \$10,000-$14,999  Total households - \$15,000-$24,999  \
# ...

# %%
zip_data.head()
# Out:
#      zip             city                 county  median_household_income  \
# 0  20001  Washington, DC   District Of Columbia                  100447.0
# 1  20002  Washington, DC   District Of Columbia                   82022.0
# 2  20003  Washington, DC   District Of Columbia                  118607.0
# 3  20004  Washington, DC   District Of Columbia                  144583.0
# 4  20005  Washington, DC   District Of Columbia                   94506.0
#
#    population                                            feature       area  \
# 0       41692  {'type': 'Feature', 'geometry': {'type': 'Poly...   5.835524
# 1       52867  {'type': 'Feature', 'geometry': {'type': 'Poly...  14.228399
# 2       26330  {'type': 'Feature', 'geometry': {'type': 'Poly...   6.447784
# 3        1610  {'type': 'Feature', 'geometry': {'type': 'Mult...   0.904905
# 4       12311  {'type': 'Feature', 'geometry': {'type': 'Poly...   1.122787
#
#         density  nml_dens   nml_inc color_key
# ...

# %%
doctor_geo.head()
# Out:
#    Unnamed: 0        lat        lng                                  name  \
# 0           0  38.917568 -77.020726  Howard University Hospital:pulmonary
# 1           1  38.905311 -77.012765                      Shiban Raina, MD
# 2           2  38.905363 -77.018377                         Aziz Salim MD
# 3           3  38.910311 -77.021587                   Abramson Randi C MD
# 4           4  38.910311 -77.021587              Hope Ferdowsian, MD, MPH
#
#                                     vicinity                      placeid  \
# 0  2041 Georgia Avenue Northwest, Washington  ChIJf2TW1OS3t4kRmYwM_D3YU9g
# 1    128 M Street Northwest #050, Washington  ChIJqVHvjcHHt4kR9bkSKfeYk6M
# 2        2175 K Street Northwest, Washington  ChIJO7BERbS3t4kRdCq1JjRVF9c
# 3      1525 7th Street Northwest, Washington  ChIJNcEa_fG3t4kROr29e7EFZJw
# 4      1525 7th Street Northwest, Washington  ChIJxfO-cZTJt4kR1eicxoihlSc
#
#      zip
# 0  20001
# 1  20001
# 2  20001
# 3  20001
# 4  20001

# %%
ins_data.head()
# Out:
#    GEO.id2 GEO.id2.1                                         HC03_VC131
# 0        0       Id2  Percent; HEALTH INSURANCE COVERAGE - Civilian ...
# 1        1     20001                                               96.0
# 2        2     20002                                               95.4
# 3        3     20003                                               97.6
# 4        4     20004                                               98.7

# %%
dr_grpby = doctor_geo[['placeid','zip']].groupby('zip')
dr_df = pd.DataFrame(dr_grpby.count())

hos_grpby = hospital_geo[['placeid','zip']].groupby('zip')
hos_df = pd.DataFrame(hos_grpby.count())

# %%
dr_df.head()
# Out:
#        placeid
# zip
# 20001       32
# 20002       58
# 20003       49
# 20004       14
# 20005       20

# %%
hos_df.head()
# Out:
#        placeid
# zip
# 20001       11
# 20002        8
# 20003        8
# 20004        5
# 20005        6

# %%
ins_data1 = ins_data.drop(0).rename(index=str, columns={"GEO.id2.1": "zip", "HC03_VC131": "Percent Insured"}).drop(['GEO.id2'], axis=1)

ins_data1.head()
# Out:
#      zip Percent Insured
# 1  20001            96.0
# 2  20002            95.4
# 3  20003            97.6
# 4  20004            98.7
# 5  20005            95.5

# %%
all_econ_data = all_econ_data.rename(index=str, columns={'Zip Code': 'zip'})

# all_econ_data = all_econ_data.set_index('zip')

all_econ_data.head()
# Out:
#      zip  Total Population  Labor Force Participation Rate  Unemployment Rate  \
# 0  20001             41692                              73                  5
# 1  20002             52867                              72                  6
# 2  20003             26330                              71                  5
# 3  20004              1610                              88                  4
# 4  20005             12311                              84                  2
#
#    Per Capita Income  Total households - Less than $10,000  \
# 0            54353.0                                  1730
# 1            49452.0                                  2501
# 2            63600.0                                   686
# 3           117432.0                                    48
# 4            76658.0                                   751
#
#    Total households - \$10,000-$14,999  Total households - \$15,000-$24,999  \
# ...

# %%
econ_select = all_econ_data[['zip', 'Total Population', 'Unemployment Rate', 'Per Capita Income']]

econ_select.head()
# Out:
#      zip  Total Population  Unemployment Rate  Per Capita Income
# 0  20001             41692                  5            54353.0
# 1  20002             52867                  6            49452.0
# 2  20003             26330                  5            63600.0
# 3  20004              1610                  4           117432.0
# 4  20005             12311                  2            76658.0

# %%
ins_data2 = ins_data1
ins_data2['Percent Insured'] = ins_data2['Percent Insured'].replace('-',0)
ins_data2 = ins_data2.astype({'zip': 'int64', 'Percent Insured':'float64'})

ins_data2.head()
# Out:
#      zip  Percent Insured
# 1  20001             96.0
# 2  20002             95.4
# 3  20003             97.6
# 4  20004             98.7
# 5  20005             95.5

# %%
econ_select1 = econ_select.merge(ins_data2, on='zip', how='inner')
econ_select1.head()
# Out:
#      zip  Total Population  Unemployment Rate  Per Capita Income  \
# 0  20001             41692                  5            54353.0
# 1  20002             52867                  6            49452.0
# 2  20003             26330                  5            63600.0
# 3  20004              1610                  4           117432.0
# 4  20005             12311                  2            76658.0
#
#    Percent Insured
# 0             96.0
# 1             95.4
# 2             97.6
# 3             98.7
# 4             95.5

# %%
econ_select2 = econ_select1.merge(hos_df, on='zip', how='left')
econ_select2 = econ_select2.rename(index=str, columns={'placeid': 'hospital facilities'})
econ_select2 = pd.DataFrame(econ_select2)

econ_select2.head()
# Out:
#      zip  Total Population  Unemployment Rate  Per Capita Income  \
# 0  20001             41692                  5            54353.0
# 1  20002             52867                  6            49452.0
# 2  20003             26330                  5            63600.0
# 3  20004              1610                  4           117432.0
# 4  20005             12311                  2            76658.0
#
#    Percent Insured  hospital facilities
# 0             96.0                 11.0
# 1             95.4                  8.0
# 2             97.6                  8.0
# 3             98.7                  5.0
# 4             95.5                  6.0

# %%
econ_select3 = econ_select2.merge(dr_df, on='zip', how='left')
econ_select3 = econ_select3.rename(index=str, columns={'placeid': 'doctors'})
econ_select3 = pd.DataFrame(econ_select3)

econ_select3.head()
# Out:
#      zip  Total Population  Unemployment Rate  Per Capita Income  \
# 0  20001             41692                  5            54353.0
# 1  20002             52867                  6            49452.0
# 2  20003             26330                  5            63600.0
# 3  20004              1610                  4           117432.0
# 4  20005             12311                  2            76658.0
#
#    Percent Insured  hospital facilities  doctors
# 0             96.0                 11.0     32.0
# 1             95.4                  8.0     58.0
# 2             97.6                  8.0     49.0
# 3             98.7                  5.0     14.0
# 4             95.5                  6.0     20.0

# %%
plt.scatter(econ_select3["Total Population"], econ_select3["hospital facilities"], color = "green", marker = "o", alpha = 0.5, linewidth = 2.1)
plt.title("Hospital Facilities vis-a-vis Total Population")
plt.xlabel("Total Population")
plt.ylabel("Hospital Facilities")


# Create a legend.
plt.legend(loc= "upper right")

# plt.savefig("../Images/Total Population_versus_Hospital Facilities.png")
# Correlation : The more populated areas do not translate into increased hospital facilities.
#Show plot.
plt.show()

# %%
plt.scatter(econ_select3["Unemployment Rate"], econ_select3["hospital facilities"], color = "red", marker = "o", alpha = 0.5, linewidth = 2.1)
plt.title("Hospital Facilities vis-a-vis Unemployment Rate")
plt.xlabel("Unemployment Rate")
plt.ylabel("Hospital Facilities")


# Create a legend.
plt.legend(loc= "upper right")

# plt.savefig("../Images/Total Population_versus_Hospital Facilities.png")
# Correlation : There is a greater presence of hospitals in the areas with less unemployment rates.
#Show plot.
plt.show()

# %%
plt.scatter(econ_select3["Per Capita Income"], econ_select3["hospital facilities"], color = "purple", marker = "o", alpha = 0.5, linewidth = 2.1)
plt.title("Hospital Facilities vis-a-vis Per Capita Income")
plt.xlabel("Per Capita Income")
plt.ylabel("Hospital Facilities")


# Create a legend.
plt.legend(loc= "upper right")

# plt.savefig("../Images/Total Population_versus_Hospital Facilities.png")
# Correlation :
#Show plot.
plt.show()

# %%
plt.scatter(econ_select3["Total Population"], econ_select3["doctors"], color = "orange", marker = "o", alpha = 0.5, linewidth = 2.1)
plt.title("doctors vis-a-vis Total Population")
plt.xlabel("Total Population")
plt.ylabel("doctors")


# Create a legend.
plt.legend(loc= "upper right")

# plt.savefig("../Images/Total Population_versus_Hospital Facilities.png")
# Correlation : The more populated areas do not translate into translate into greater availability of doctors.
#Show plot.
plt.show()

# %%
plt.scatter(econ_select3["Unemployment Rate"], econ_select3["doctors"], color = "blue", marker = "o", alpha = 0.5, linewidth = 2.1)
plt.title("doctors vis-a-vis Unemployment Rate")
plt.xlabel("Unemployment Rate")
plt.ylabel("doctors")


# Create a legend.
plt.legend(loc= "upper right")

# plt.savefig("../Images/Total Population_versus_Hospital Facilities.png")
# Correlation : There is a greater presence of doctors in the areas with less unemployment rates.
#Show plot.
plt.show()

# %%
plt.scatter(econ_select3["Per Capita Income"], econ_select3["doctors"], color = "yellow", marker = "o", alpha = 0.5, linewidth = 2.1)
plt.title("doctors vis-a-vis Per Capita Income")
plt.xlabel("Per Capita Income")
plt.ylabel("doctors")


# Create a legend.
plt.legend(loc= "upper right")

# plt.savefig("../Images/Total Population_versus_Hospital Facilities.png")
# Correlation :
#Show plot.
plt.show()

# %%
plt.scatter(econ_select3["Per Capita Income"], econ_select3["Percent Insured"], color = "red", marker = "o", alpha = 0.5, linewidth = 2.1)
plt.title("Percent Insured vis-a-vis Per Capita Income")
plt.xlabel("Per Capita Income")
plt.ylabel("Percent Insured")


# Create a legend.
plt.legend(loc= "upper right")

# plt.savefig("../Images/Total Population_versus_Hospital Facilities.png")

#Show plot.
plt.show()

# %%
plt.scatter(econ_select3["Percent Insured"], econ_select3["Total Population"], color = "brown", marker = "o", alpha = 0.5, linewidth = 2.1)
plt.title("Percent Insured vis-a-vis Total Population")
plt.xlabel("Percent Insured")
plt.ylabel("Total Population")


# Create a legend.
plt.legend(loc= "upper right")

# plt.savefig("../Images/Total Population_versus_Hospital Facilities.png")

#Show plot.
plt.show()

# %%
plt.scatter(econ_select3["Unemployment Rate"], econ_select3["Percent Insured"], color = "magenta", marker = "o", alpha = 0.5, linewidth = 2.1)
plt.title("Percent Insured vis-a-vis Unemployment Rate")
plt.xlabel("Unemployment Rate")
plt.ylabel("Percent Insured")


# Create a legend.
plt.legend(loc= "upper right")

# plt.savefig("../Images/Total Population_versus_Hospital Facilities.png")

# Correlation : There is a greater percentage of insured people in the areas with less unemployment rates.
#Show plot.
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-95-b75087928090> in <module>
#       5 x_axis = np.arange(0, x_limit, 2.5)
#       6
# ----> 7 plt.scatter(x_axis, econ_select3["Percent Insured"], color = "magenta", marker = "o", alpha = 0.5, linewidth = 2.1)
#       8 plt.title("Percent Insured vis-a-vis Unemployment Rate")
#       9 plt.xlabel("Unemployment Rate")
#
# ~/anaconda3/envs/Pythondata/lib/python3.6/site-packages/matplotlib/pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, data, **kwargs)
#    2862         vmin=vmin, vmax=vmax, alpha=alpha, linewidths=linewidths,
#    2863         verts=verts, edgecolors=edgecolors, **({"data": data} if data
# -> 2864         is not None else {}), **kwargs)
#    2865     sci(__ret)
#    2866     return __ret
#
# ...

# %%
def calculate_color(pop):
    mpl_color = viridis(pop)
    gmaps_color = to_hex(mpl_color, keep_alpha=False)
    return gmaps_color

# %%
min_emp = min(econ_select3['Unemployment Rate'])
max_emp = max(econ_select3['Unemployment Rate'])
emp_range = max_emp - min_emp

econ_select3['nml_emp'] = (1 - (econ_select3['Unemployment Rate'] - min_emp)/emp_range)

econ_select3.head()
# Out:
#      zip  Total Population  Unemployment Rate  Per Capita Income  \
# 0  20001             41692                  5            54353.0
# 1  20002             52867                  6            49452.0
# 2  20003             26330                  5            63600.0
# 3  20004              1610                  4           117432.0
# 4  20005             12311                  2            76658.0
#
#    Percent Insured  hospital facilities  doctors  nml_emp
# 0             96.0                 11.0     32.0     0.95
# 1             95.4                  8.0     58.0     0.94
# 2             97.6                  8.0     49.0     0.95
# 3             98.7                  5.0     14.0     0.96
# 4             95.5                  6.0     20.0     0.98

# %%
min_inc = min(econ_select3['Per Capita Income'])
max_inc = max(econ_select3['Per Capita Income'])
inc_range = max_inc - min_inc

econ_select3['nml_inc'] = ((econ_select3['Per Capita Income'] - min_emp)/inc_range)

econ_select3.head()
# Out:
#      zip  Total Population  Unemployment Rate  Per Capita Income  \
# 0  20001             41692                  5            54353.0
# 1  20002             52867                  6            49452.0
# 2  20003             26330                  5            63600.0
# 3  20004              1610                  4           117432.0
# 4  20005             12311                  2            76658.0
#
#    Percent Insured  hospital facilities  doctors  nml_emp   nml_inc
# 0             96.0                 11.0     32.0     0.95  0.182314
# 1             95.4                  8.0     58.0     0.94  0.165875
# 2             97.6                  8.0     49.0     0.95  0.213330
# 3             98.7                  5.0     14.0     0.96  0.393897
# 4             95.5                  6.0     20.0     0.98  0.257130

# %%
econ_select3['nml_ins'] = (econ_select3['Percent Insured'] / 100)

econ_select3.head()
# Out:
#      zip  Total Population  Unemployment Rate  Per Capita Income  \
# 0  20001             41692                  5            54353.0
# 1  20002             52867                  6            49452.0
# 2  20003             26330                  5            63600.0
# 3  20004              1610                  4           117432.0
# 4  20005             12311                  2            76658.0
#
#    Percent Insured  hospital facilities  doctors  nml_emp   nml_inc  nml_ins
# 0             96.0                 11.0     32.0     0.95  0.182314    0.960
# 1             95.4                  8.0     58.0     0.94  0.165875    0.954
# 2             97.6                  8.0     49.0     0.95  0.213330    0.976
# 3             98.7                  5.0     14.0     0.96  0.393897    0.987
# 4             95.5                  6.0     20.0     0.98  0.257130    0.955

# %%
colors = []

for pop in econ_select3['nml_inc'].tolist():
    try:
        color = calculate_color(pop)
    except KeyError:
        color = (0, 0, 0, 0.3)
        print('key error')
    colors.append(color)

# %%
econ_select3['color_key_inc'] = colors

econ_select3.head()
# Out:
#      zip  Total Population  Unemployment Rate  Per Capita Income  \
# 0  20001             41692                  5            54353.0
# 1  20002             52867                  6            49452.0
# 2  20003             26330                  5            63600.0
# 3  20004              1610                  4           117432.0
# 4  20005             12311                  2            76658.0
#
#    Percent Insured  hospital facilities  doctors  nml_emp   nml_inc  nml_ins  \
# 0             96.0                 11.0     32.0     0.95  0.182314    0.960
# 1             95.4                  8.0     58.0     0.94  0.165875    0.954
# 2             97.6                  8.0     49.0     0.95  0.213330    0.976
# 3             98.7                  5.0     14.0     0.96  0.393897    0.987
# 4             95.5                  6.0     20.0     0.98  0.257130    0.955
#
#   color_key_inc
# 0       #433e85
# 1       #443983
# 2       #3f4788
# 3       #2a768e
# 4       #3a538b

# %%
colors = []

for pop in econ_select3['nml_emp'].tolist():
    try:
        color = calculate_color(pop)
    except KeyError:
        color = (0, 0, 0, 0.3)
        print('key error')
    colors.append(color)

# %%
econ_select3['color_key_emp'] = colors

econ_select3.head()
# Out:
#      zip  Total Population  Unemployment Rate  Per Capita Income  \
# 0  20001             41692                  5            54353.0
# 1  20002             52867                  6            49452.0
# 2  20003             26330                  5            63600.0
# 3  20004              1610                  4           117432.0
# 4  20005             12311                  2            76658.0
#
#    Percent Insured  hospital facilities  doctors  nml_emp   nml_inc  nml_ins  \
# 0             96.0                 11.0     32.0     0.95  0.182314    0.960
# 1             95.4                  8.0     58.0     0.94  0.165875    0.954
# 2             97.6                  8.0     49.0     0.95  0.213330    0.976
# 3             98.7                  5.0     14.0     0.96  0.393897    0.987
# 4             95.5                  6.0     20.0     0.98  0.257130    0.955
#
#   color_key_inc color_key_emp
# 0       #433e85       #dfe318
# 1       #443983       #d8e219
# ...

# %%
colors = []

for pop in econ_select3['nml_ins'].tolist():
    try:
        color = calculate_color(pop)
    except KeyError:
        color = (0, 0, 0, 0.3)
        print('key error')
    colors.append(color)

# %%
econ_select3['color_key_ins'] = colors

econ_select3.head()
# Out:
#      zip  Total Population  Unemployment Rate  Per Capita Income  \
# 0  20001             41692                  5            54353.0
# 1  20002             52867                  6            49452.0
# 2  20003             26330                  5            63600.0
# 3  20004              1610                  4           117432.0
# 4  20005             12311                  2            76658.0
#
#    Percent Insured  hospital facilities  doctors  nml_emp   nml_inc  nml_ins  \
# 0             96.0                 11.0     32.0     0.95  0.182314    0.960
# 1             95.4                  8.0     58.0     0.94  0.165875    0.954
# 2             97.6                  8.0     49.0     0.95  0.213330    0.976
# 3             98.7                  5.0     14.0     0.96  0.393897    0.987
# 4             95.5                  6.0     20.0     0.98  0.257130    0.955
#
#   color_key_inc color_key_emp color_key_ins
# 0       #433e85       #dfe318       #e5e419
# ...

# %%
zip_data.head()
# Out:
#      zip             city                 county  median_household_income  \
# 0  20001  Washington, DC   District Of Columbia                  100447.0
# 1  20002  Washington, DC   District Of Columbia                   82022.0
# 2  20003  Washington, DC   District Of Columbia                  118607.0
# 3  20004  Washington, DC   District Of Columbia                  144583.0
# 4  20005  Washington, DC   District Of Columbia                   94506.0
#
#    population                                            feature       area  \
# 0       41692  {'type': 'Feature', 'geometry': {'type': 'Poly...   5.835524
# 1       52867  {'type': 'Feature', 'geometry': {'type': 'Poly...  14.228399
# 2       26330  {'type': 'Feature', 'geometry': {'type': 'Poly...   6.447784
# 3        1610  {'type': 'Feature', 'geometry': {'type': 'Mult...   0.904905
# 4       12311  {'type': 'Feature', 'geometry': {'type': 'Poly...   1.122787
#
#         density  nml_dens   nml_inc color_key
# ...

# %%
econ_main = zip_data[['zip','feature','area','density']].rename(index=str, columns={'area': 'area km'})

econ_main = econ_main.merge(econ_select3, on='zip', how='left').fillna(0)

# %%
econ_main.to_csv('../primary_data.csv', encoding='utf-8')

# %%
feat_list = []
for feature in econ_main['feature']:
    feat_list.append(ast.literal_eval(feature))

geoj_clean = {'type': 'FeatureCollection', 'features': feat_list}

with open('../zcta_map/resources/features.json', 'w') as outfile:  
    json.dump(geoj_clean, outfile)
