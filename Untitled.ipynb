# %%
import pandas as pd
import numpy as py
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("primary_data.csv")
data.head()
# Out:
#    Unnamed: 0    zip                                            feature  \
# 0           0  20001  {'type': 'Feature', 'geometry': {'type': 'Poly...
# 1           1  20002  {'type': 'Feature', 'geometry': {'type': 'Poly...
# 2           2  20003  {'type': 'Feature', 'geometry': {'type': 'Poly...
# 3           3  20004  {'type': 'Feature', 'geometry': {'type': 'Mult...
# 4           4  20005  {'type': 'Feature', 'geometry': {'type': 'Poly...
#
#      area km       density  Total Population  Unemployment Rate  \
# 0   5.835524   7144.516970             41692                  5
# 1  14.228399   3715.597280             52867                  6
# 2   6.447784   4083.573672             26330                  5
# 3   0.904905   1779.192084              1610                  4
# 4   1.122787  10964.678013             12311                  2
#
#    Per Capita Income  Percent Insured  hospital facilities  doctors   nml_emp  \
# 0            54353.0             96.0                 11.0     32.0  0.782609
# 1            49452.0             95.4                  8.0     58.0  0.739130
# 2            63600.0             97.6                  8.0     49.0  0.782609
# 3           117432.0             98.7                  5.0     14.0  0.826087
# 4            76658.0             95.5                  6.0     20.0  0.913043
#
#     nml_inc  nml_ins color_key_inc color_key_emp color_key_ins
# 0  0.383988    0.960       #fed884       #70c164       #0a7b41
# 1  0.336126    0.954       #fdc171       #8ccd67       #0b7d42
# 2  0.474292    0.976       #fff7b2       #70c164       #06733d
# 3  1.000000    0.987       #006837       #51b35e       #036e3a
# 4  0.601813    0.955       #d7ee8a       #16914d       #0b7d42

# %%
data["Per Capita Income"].max()

plt.hist(data["Per Capita Income"], bins=10)
plt.ylabel('No of times')
plt.show()

data.head()
# Out:
#    Unnamed: 0    zip                                            feature  \
# 0           0  20001  {'type': 'Feature', 'geometry': {'type': 'Poly...
# 1           1  20002  {'type': 'Feature', 'geometry': {'type': 'Poly...
# 2           2  20003  {'type': 'Feature', 'geometry': {'type': 'Poly...
# 3           3  20004  {'type': 'Feature', 'geometry': {'type': 'Mult...
# 4           4  20005  {'type': 'Feature', 'geometry': {'type': 'Poly...
#
#      area km       density  Total Population  Unemployment Rate  \
# 0   5.835524   7144.516970             41692                  5
# 1  14.228399   3715.597280             52867                  6
# 2   6.447784   4083.573672             26330                  5
# 3   0.904905   1779.192084              1610                  4
# 4   1.122787  10964.678013             12311                  2
#
#    Per Capita Income  Percent Insured  hospital facilities  doctors   nml_emp  \
# 0            54353.0             96.0                 11.0     32.0  0.782609
# 1            49452.0             95.4                  8.0     58.0  0.739130
# 2            63600.0             97.6                  8.0     49.0  0.782609
# 3           117432.0             98.7                  5.0     14.0  0.826087
# 4            76658.0             95.5                  6.0     20.0  0.913043
#
#     nml_inc  nml_ins color_key_inc color_key_emp color_key_ins
# 0  0.383988    0.960       #fed884       #70c164       #0a7b41
# 1  0.336126    0.954       #fdc171       #8ccd67       #0b7d42
# 2  0.474292    0.976       #fff7b2       #70c164       #06733d
# 3  1.000000    0.987       #006837       #51b35e       #036e3a
# 4  0.601813    0.955       #d7ee8a       #16914d       #0b7d42

# %%
# Sample bins.
income_bins = py.array([0, 10000,20000,30000, 40000,50000 ,60000, 70000,80000, 90000,100000,120000])
bin_names = ["0, 10000","10000,20000","20000,30000","30000, 40000","40000,50000","50000 ,60000","60000, 70000","70000,80000","80000, 90000"," 90000,100000","100000,120000"]

#Create new DataFrame and bin
bindata = data
bindata["Inc Group"] = pd.cut(bindata["Per Capita Income"], income_bins, labels=bin_names)

#Group by budgets and find value means
new = bindata.groupby(['Inc Group']).sum()#.reset_index()

new.plot.bar(y="Total Population", figsize=(7,4))
data["Per Capita Income"].max()
new.head()
# Out:
#               Unnamed: 0     zip     area km       density  Total Population  \
# Inc Group
# 0, 10000               0       0    0.000000      0.000000                 0
# 10000,20000            5   20006    0.920409   3020.397748              2780
# 20000,30000          492  329865  222.636989  30854.005406            381701
# 30000, 40000         577  274070  160.619801  26625.529249            298810
# 40000,50000          569  256893  144.396629  39401.053126            364967
#
#               Unemployment Rate  Per Capita Income  Percent Insured  \
# Inc Group
# 0, 10000                      0                0.0              0.0
# 10000,20000                   9            15033.0             96.3
# 20000,30000                 149           404869.0           1365.1
# 30000, 40000                 79           452002.0           1114.0
# 40000,50000                  57           541266.0           1055.8
#
#               hospital facilities  doctors   nml_emp   nml_inc  nml_ins
# Inc Group
# 0, 10000                      0.0      0.0  0.000000  0.000000    0.000
# 10000,20000                   9.0     20.0  0.608696  0.000000    0.963
# 20000,30000                  10.0    675.0  9.521739  1.604908   13.651
# 30000, 40000                 29.0    503.0  9.565217  2.505620   11.140
# 40000,50000                 133.0    758.0  9.521739  3.524156   10.558

# %%
income_bins = py.array([0, 10000,20000,30000, 40000,50000 ,60000, 70000,80000, 90000,100000,120000])
bin_names = ["0, 10000","10000,20000","20000,30000","30000, 40000","40000,50000","50000 ,60000","60000, 70000","70000,80000","80000, 90000"," 90000,100000","100000,120000"]

#Create new DataFrame and bin
bindata = data
bindata["Inc Group"] = pd.cut(bindata["Per Capita Income"], income_bins, labels=bin_names)

#Group by budgets and find value means
new = bindata.groupby(['Inc Group']).sum()#.reset_index()

new.plot.bar(y="hospital facilities", figsize=(7,4))
data["Per Capita Income"].max()
# Out:
# 117432.0

# %%
bindata.head()
plt.hist(data["nml_inc"], bins=5)
plt.ylabel('No of times')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'nml_inc'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-27-09512d8ae899> in <module>
#       1 bindata.head()
# ----> 2 plt.hist(data["nml_inc"], bins=5)
#       3 plt.ylabel('No of times')
#       4 plt.show()
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2925             if self.columns.nlevels > 1:
#    2926                 return self._getitem_multilevel(key)
# -> 2927             indexer = self.columns.get_loc(key)
#    2928             if is_integer(indexer):
#    2929                 indexer = [indexer]
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
# -> 2659                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2660         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2661         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'nml_inc'
